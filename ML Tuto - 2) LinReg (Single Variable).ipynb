# %% [markdown]
# Machine learning is set of techniques to make computers better at doing things that human (traditionally) can do better than machines

# %% [markdown]
# Machine learning involves making machines learn things like humans do

# %% [markdown]
# ![image.png](attachment:2f2eb8f5-9e11-4c77-8978-280fa1c67492.png)

# %% [markdown]
# ![image.png](attachment:ae7c3c90-b1b8-4687-9528-96073da1551c.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

df = pd.read_csv("homeprices.csv")
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#Scatter Plot

# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US$)')
plt.scatter(df.area,df.price, color='red', marker = '+')
plt.show()

# %%
#Create linear regression object
#Fit the data = training the linear regression model using the available data points

reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)

#Ready to predict the prices
# Out:
# LinearRegression()

# %%
reg.predict([[3000]])
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([587979.45205479])

# %%
#coefficient = m , y =mx+b

reg.coef_
# Out:
# array([135.78767123])

# %%
#intercept = b , y = mx + b

reg.intercept_
# Out:
# 180616.43835616432

# %%
#y = m*x + b
# Find y
# x = 3300 (nilai yang nak predict, area)
# m = coefficient
# b = intercept

135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
# %matplotlib inline
plt.xlabel('area', fontsize=20)
plt.ylabel('price', fontsize=20)
plt.scatter(df.area,df.price, color='red', marker = '+')
plt.plot(df.area,reg.predict(df[['area']]), color='blue')
plt.show()

# %%
import pandas as pd
df2 = pd.read_csv("areas.csv")
df2.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(df2)

# %%
df2['prices'] = p

# %%
df2.head(5)
# Out:
#    area         prices
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2300  492928.082192
# 3  3540  661304.794521
# 4  4120  740061.643836

# %%
df2.to_csv("prediction.csv", index = False)
